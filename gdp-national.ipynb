# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("GDP.csv")

# %%
df.head()
# Out:
#   observation_date      GDP
# 0       1947-01-01  243.164
# 1       1947-04-01  245.968
# 2       1947-07-01  249.585
# 3       1947-10-01  259.745
# 4       1948-01-01  265.742

# %%
df.shape
# Out:
# (314, 2)

# %%
min(df["GDP"])
# Out:
# 243.164

# %%
max(df["GDP"])
# Out:
# 30353.902

# %%
df.plot(x='observation_date', y='GDP', title='Line Plot of GDP', figsize=(10,6))
plt.show()

# %%
df_new = df
df_new["observation_date"] = pd.to_datetime(df_new["observation_date"])
df_new
# Out:
#     observation_date        GDP
# 0         1947-01-01    243.164
# 1         1947-04-01    245.968
# 2         1947-07-01    249.585
# 3         1947-10-01    259.745
# 4         1948-01-01    265.742
# ..               ...        ...
# 309       2024-04-01  29016.714
# 310       2024-07-01  29374.914
# 311       2024-10-01  29723.864
# 312       2025-01-01  29962.047
# 313       2025-04-01  30353.902
#
# [314 rows x 2 columns]

# %%
start_date = '1990-01-01'
df_new = df_new[df_new['observation_date'] >= start_date]
df_new
# Out:
#     observation_date        GDP
# 172       1990-01-01   5872.701
# 173       1990-04-01   5960.028
# 174       1990-07-01   6015.116
# 175       1990-10-01   6004.733
# 176       1991-01-01   6035.178
# ..               ...        ...
# 309       2024-04-01  29016.714
# 310       2024-07-01  29374.914
# 311       2024-10-01  29723.864
# 312       2025-01-01  29962.047
# 313       2025-04-01  30353.902
#
# [142 rows x 2 columns]

# %%
df_new.plot(x='observation_date', y='GDP', title='Line Plot of GDP', figsize=(10,6))
plt.show()

# %%
df.isnull().sum()
# Out:
# observation_date    0
# GDP                 0
# dtype: int64

# %%
df.dtypes
# Out:
# observation_date    datetime64[ns]
# GDP                        float64
# dtype: object
